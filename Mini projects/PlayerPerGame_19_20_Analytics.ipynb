# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
df_player_19_20 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\player_per_game_2019-2020.txt', sep=',')
df_player_19_20
# Out:
#       Rk                              Player Pos  Age   Tm   G  GS    MP   FG  \
# 0      1              Steven Adams\adamsst01   C   26  OKC  63  63  26.7  4.5
# 1      2               Bam Adebayo\adebaba01  PF   22  MIA  72  72  33.6  6.1
# 2      3         LaMarcus Aldridge\aldrila01   C   34  SAS  53  53  33.1  7.4
# 3      4            Kyle Alexander\alexaky01   C   23  MIA   2   0   6.5  0.5
# 4      5  Nickeil Alexander-Walker\alexani01  SG   21  NOP  47   1  12.6  2.1
# ..   ...                                 ...  ..  ...  ...  ..  ..   ...  ...
# 646  525                Trae Young\youngtr01  PG   21  ATL  60  60  35.3  9.1
# 647  526               Cody Zeller\zelleco01   C   27  CHO  58  39  23.1  4.3
# 648  527              Tyler Zeller\zellety01   C   30  SAS   2   0   2.0  0.5
# 649  528                Ante Žižić\zizican01   C   23  CLE  22   0  10.0  1.9
# 650  529               Ivica Zubac\zubaciv01   C   22  LAC  72  70  18.4  3.3
#
# ...

# %%
df_player_19_20.head(30)
# Out:
#     Rk                              Player Pos  Age   Tm   G  GS    MP    FG  \
# 0    1              Steven Adams\adamsst01   C   26  OKC  63  63  26.7   4.5
# 1    2               Bam Adebayo\adebaba01  PF   22  MIA  72  72  33.6   6.1
# 2    3         LaMarcus Aldridge\aldrila01   C   34  SAS  53  53  33.1   7.4
# 3    4            Kyle Alexander\alexaky01   C   23  MIA   2   0   6.5   0.5
# 4    5  Nickeil Alexander-Walker\alexani01  SG   21  NOP  47   1  12.6   2.1
# 5    6             Grayson Allen\allengr01  SG   24  MEM  38   0  18.9   3.1
# 6    7             Jarrett Allen\allenja01   C   21  BRK  70  64  26.5   4.3
# 7    8              Kadeem Allen\allenka01  PG   27  NYK  10   0  11.7   1.9
# 8    9           Al-Farouq Aminu\aminual01  PF   29  ORL  18   2  21.1   1.4
# 9   10           Justin Anderson\anderju01  SG   26  BRK  10   1  10.7   1.0
# 10  11             Kyle Anderson\anderky01  SF   26  MEM  67  28  19.9   2.3
# ...

# %%
for i in range(0, len(df_player_19_20.Player)):
    df_player_19_20.Player[i] = df_player_19_20.Player.str.split('\\')[i][0]
# Out:
# <ipython-input-57-ccb6c9552a6c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_player_19_20.Player[i] = df_player_19_20.Player.str.split('\\')[i][0]

# %%
df_player_19_20.head()
# Out:
#    Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0   1              Steven Adams   C   26  OKC  63  63  26.7  4.5   7.6  ...
# 1   2               Bam Adebayo  PF   22  MIA  72  72  33.6  6.1  11.0  ...
# 2   3         LaMarcus Aldridge   C   34  SAS  53  53  33.1  7.4  15.0  ...
# 3   4            Kyle Alexander   C   23  MIA   2   0   6.5  0.5   1.0  ...
# 4   5  Nickeil Alexander-Walker  SG   21  NOP  47   1  12.6  2.1   5.7  ...
#
#      FT%  ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.582  3.3  6.0   9.3  2.3  0.8  1.1  1.5  1.9  10.9
# 1  0.691  2.4  7.8  10.2  5.1  1.1  1.3  2.8  2.5  15.9
# 2  0.827  1.9  5.5   7.4  2.4  0.7  1.6  1.4  2.4  18.9
# 3    NaN  1.0  0.5   1.5  0.0  0.0  0.0  0.5  0.5   1.0
# 4  0.676  0.2  1.6   1.8  1.9  0.4  0.2  1.1  1.2   5.7
#
# [5 rows x 30 columns]

# %%
df_player_19_20.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
def stats(stats_list):
    global df_player_19_20
    
    for x in stats_list:
        df_player_19_20 = df_player_19_20.sort_values(by=x, ascending=False)
        fig, ax = plt.subplots(figsize=(20,6))
        ax = sns.barplot(x=df_player_19_20.iloc[0:30, 1], y=df_player_19_20[x], data=df_player_19_20, 
                         dodge=False)
        ax.set_xlabel(xlabel='Players')
        ax.set_ylabel(ylabel=str(x))
        
        #rects=ax.patches
        #labels=['{:04.2f}'.format(i) for i in df_player_19_20[x]]
        
        #for rect, label in zip(rects, labels):
            #height = rect.get_height()
            #ax.text(rect.get_x() + rect.get_width() / 2, height + 0.02, label,
                            #ha='center', va='bottom')
        
        plt.xticks(rotation=90)
        plt.show()

# %%
stats_list=['PTS', 'eFG%', 'ORB', 'DRB', 'AST', 'STL', 'BLK', 'TOV']
stats(stats_list)

# %%
df_player_19_20[['Player', 'eFG%']].sort_values(by='eFG%', ascending=False).head(20)
# Out:
#                    Player   eFG%
# 13   Kostas Antetokounmpo  1.000
# 601           Noah Vonleh  0.917
# 202            Tacko Fall  0.786
# 118        Tyson Chandler  0.778
# 254            Donta Hall  0.778
# 603             Dean Wade  0.769
# 440      Johnathan Motley  0.767
# 524     Mitchell Robinson  0.742
# 298         Dwight Howard  0.735
# 637       Robert Williams  0.727
# 354          John Konchar  0.716
# 595     Jarred Vanderbilt  0.714
# 219        Daniel Gafford  0.701
# 497        Shamorie Ponds  0.700
# 143            Tyler Cook  0.700
# 229           Rudy Gobert  0.693
# 117   Willie Cauley-Stein  0.689
# 457          Nerlens Noel  0.686
# 274           John Henson  0.686
# 335          Damian Jones  0.685

# %%
df_player_19_20[df_player_19_20['Player'] == 'Andre Drummond'][['Tm', 'MP', 'ORB' ]]
# Out:
#       Tm    MP  ORB
# 184  DET  33.8  4.6
# 183  TOT  33.0  4.4
# 185  CLE  28.1  3.0

# %%
df_player_19_20[df_player_19_20['Player'] == 'Andre Drummond']['ORB'].values.mean()
# Out:
# 4.0

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax = sns.barplot(x=df_player_19_20.iloc[0:30, 1], 
                 y=df_player_19_20.sort_values(by=['MP', 'eFG%'], ascending=False).iloc[:, 17], 
                 data=df_player_19_20)

rects=ax.patches
labels=['{:04.2f}'.format(i) for i in df_player_19_20['eFG%']]
        
#for rect, label in zip(rects, labels):
    #height = rect.get_height()
    #ax.text(rect.get_x() + rect.get_width() / 2, height + 0.02, label,
            #ha='center', va='bottom')
plt.xticks(rotation=90)
plt.show()

# %%
df_misc_stats_19_20 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\nba_miscellaneous_stats_2019-2020.csv', sep=',')
df_misc_stats_19_20.head()
# Out:
#    Rk                   Team   Age   W   L  PW  PL    MOV   SOS   SRS  ...  \
# 0   1       Milwaukee Bucks*  29.2  56  17  57  16  10.08 -0.67  9.41  ...
# 1   2  Los Angeles Clippers*  27.4  49  23  50  22   6.44  0.21  6.66  ...
# 2   3    Los Angeles Lakers*  29.5  52  19  48  23   5.79  0.49  6.28  ...
# 3   4       Toronto Raptors*  26.6  53  19  50  22   6.24 -0.26  5.97  ...
# 4   5        Boston Celtics*  25.3  48  24  50  22   6.31 -0.47  5.83  ...
#
#    off-TOV%  off-ORB%  off-FT/FGA  dff-eFG%  dff-TOV%  dff-DRB%  dff-FT/FGA  \
# 0      12.9      20.7       0.201     0.489      12.0      81.6       0.178
# 1      12.6      23.5       0.233     0.506      12.2      77.6       0.206
# 2      13.3      24.5       0.201     0.515      14.1      78.8       0.205
# 3      13.1      21.3       0.210     0.502      14.6      76.7       0.202
# 4      12.2      23.9       0.207     0.509      13.5      77.4       0.215
#
#               Arena  Attend.  Attend./G
# ...

# %%
df_misc_stats_19_20['Season'] = '19-20'

# %%
df_misc_stats_19_20.columns
# Out:
# Index(['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
#        'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'off-eFG%', 'off-TOV%',
#        'off-ORB%', 'off-FT/FGA', 'dff-eFG%', 'dff-TOV%', 'dff-DRB%',
#        'dff-FT/FGA', 'Arena', 'Attend.', 'Attend./G', 'Season'],
#       dtype='object')

# %%
df_misc_stats_19_20.W.unique()
# Out:
# array([56, 49, 52, 53, 48, 43, 44, 46, 45, 34, 30, 35, 32, 33, 31, 22, 19,
#        20, 25, 21, 23, 15], dtype=int64)

# %%
df_misc_stats_18_19 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\nba_miscellaneous_stats_2018-2019.csv', sep=',')
df_misc_stats_18_19.head()
# Out:
#    Rk                    Team   Age   W   L  PW  PL   MOV   SOS   SRS  ...  \
# 0   1        Milwaukee Bucks*  26.9  60  22  61  21  8.87 -0.82  8.04  ...
# 1   2  Golden State Warriors*  28.4  57  25  56  26  6.46 -0.04  6.42  ...
# 2   3        Toronto Raptors*  27.3  58  24  56  26  6.09 -0.60  5.49  ...
# 3   4              Utah Jazz*  27.3  50  32  54  28  5.26  0.03  5.28  ...
# 4   5        Houston Rockets*  29.2  53  29  53  29  4.77  0.19  4.96  ...
#
#    off-TOV%  off-ORB%  off-FT/FGA  dff-eFG%  dff-TOV%  dff-DRB%  dff-FT/FGA  \
# 0      12.0      20.8       0.197     0.503      11.5      80.3       0.162
# 1      12.6      22.5       0.182     0.508      11.7      77.1       0.205
# 2      12.4      21.9       0.198     0.509      13.1      77.1       0.190
# 3      13.4      22.9       0.217     0.507      12.4      80.3       0.189
# 4      12.0      22.8       0.221     0.525      13.4      74.4       0.210
#
#                      Arena  Attend.  Attend./G
# ...

# %%
df_misc_stats_18_19['Season'] = '18-19'

# %%
df_misc_stats_17_18 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\nba_miscellaneous_stats_2017-2018.txt', sep=',')
df_misc_stats_17_18.head()
# Out:
#    1        Houston Rockets*  29.8  65  17  61  21  8.48  -0.27  8.21  ...  \
# 0  2        Toronto Raptors*  25.8  59  23  60  22  7.78  -0.49  7.29  ...
# 1  3  Golden State Warriors*  28.8  58  24  56  26  5.98  -0.19  5.79  ...
# 2  4              Utah Jazz*  26.7  48  34  53  29  4.30   0.17  4.47  ...
# 3  5     Philadelphia 76ers*  25.8  52  30  53  29  4.50  -0.20  4.30  ...
# 4  6  Oklahoma City Thunder*  27.3  48  34  50  32  3.41   0.00  3.42  ...
#
#    12.7  21.3   .233   .521  13.4  79.9   .171            Toyota Center  \
# 0  12.1  23.0  0.198  0.501  13.0  77.7  0.212        Air Canada Centre
# 1  14.1  21.0  0.195  0.504  12.6  76.3  0.186             Oracle Arena
# 2  13.7  21.5  0.202  0.506  14.0  79.8  0.190  Vivint Smart Home Arena
# 3  14.6  25.3  0.198  0.492  12.6  78.6  0.218       Wells Fargo Center
# 4  12.4  27.7  0.197  0.525  14.7  77.4  0.193  Chesapeake Energy Arena
#
#    732722  17871
# 0  813431  19840
# 1  803436  19596
# 2  734806  17922
# ...

# %%
df_misc_stats_17_18.columns = ['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
       'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'off-eFG%', 'off-TOV%',
       'off-ORB%', 'off-FT/FGA', 'dff-eFG%', 'dff-TOV%', 'dff-DRB%',
       'dff-FT/FGA', 'Arena', 'Attend.', 'Attend./G']

# %%
df_misc_stats_17_18['Season'] = '17-18'

# %%
df_misc_stats_16_17 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\nba_miscellaneous_stats_2016-2017.txt', sep=',')
df_misc_stats_16_17.head()
# Out:
#    1 Golden State Warriors*  28.2  67  15  67.1  15.1  11.63  -0.28  11.35  \
# 0  2     San Antonio Spurs*  29.6  61  21    60    22   7.20  -0.06   7.13
# 1  3       Houston Rockets*  27.4  55  27    55    27   5.77   0.08   5.84
# 2  4  Los Angeles Clippers*  30.0  51  31    52    30   4.29   0.13   4.42
# 3  5             Utah Jazz*  26.8  51  31    52    30   3.94   0.06   4.00
# 4  6       Toronto Raptors*  26.1  51  31    52    30   4.21  -0.56   3.65
#
#    ...  13.2  22.8   .204   .486  13.5  74.9   .198             Oracle Arena  \
# 0  ...  12.6  24.0  0.210  0.492  13.5  77.6  0.192              AT&T Center
# 1  ...  13.3  24.6  0.233  0.519  13.2  75.8  0.194            Toyota Center
# 2  ...  12.0  21.5  0.233  0.506  12.1  76.9  0.211           STAPLES Center
# 3  ...  13.2  23.2  0.215  0.493  11.8  78.9  0.195  Vivint Smart Home Arena
# 4  ...  11.8  25.0  0.233  0.507  13.5  76.3  0.223        Air Canada Centre
#
#    803436  19596
# 0  755347  18423
# ...

# %%
df_misc_stats_16_17.columns = ['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
       'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'off-eFG%', 'off-TOV%',
       'off-ORB%', 'off-FT/FGA', 'dff-eFG%', 'dff-TOV%', 'dff-DRB%',
       'dff-FT/FGA', 'Arena', 'Attend.', 'Attend./G']

# %%
df_misc_stats_16_17['Season'] = '16-17'

# %%
df_misc_stats_15_16 = pd.read_csv(r'C:\Users\Admin\Documents\Data\nba_data\nba_miscellaneous_stats_2015-2016.txt', sep=',')
df_misc_stats_15_16.head()
# Out:
#    1  Golden State Warriors*  27.4  73   9  65  17  10.76  -0.38  10.38  ...  \
# 0  2      San Antonio Spurs*  30.3  67  15  67  15  10.63  -0.36  10.28  ...
# 1  3  Oklahoma City Thunder*  25.8  55  27  59  23   7.28  -0.19   7.09  ...
# 2  4    Cleveland Cavaliers*  28.1  57  25  57  25   6.00  -0.55   5.45  ...
# 3  5   Los Angeles Clippers*  29.7  53  29  53  29   4.28  -0.15   4.13  ...
# 4  6        Toronto Raptors*  26.3  56  26  53  29   4.50  -0.42   4.08  ...
#
#    13.5  23.5   .191   .479  12.6  76.0   .208             Oracle Arena  \
# 0  12.4  23.0  0.197  0.477  14.1  79.1  0.182              AT&T Center
# 1  14.0  31.1  0.228  0.484  11.7  76.0  0.205  Chesapeake Energy Arena
# 2  12.7  25.1  0.194  0.496  12.6  78.5  0.205      Quicken Loans Arena
# 3  12.1  20.1  0.220  0.480  13.8  73.8  0.222           STAPLES Center
# 4  12.3  24.6  0.255  0.498  12.7  77.7  0.201        Air Canada Centre
#
#    803436  19596
# 0  756445  18450
# 1  746323  18203
# ...

# %%
df_misc_stats_15_16.columns = ['Rk', 'Team', 'Age', 'W', 'L', 'PW', 'PL', 'MOV', 'SOS', 'SRS', 'ORtg',
       'DRtg', 'NRtg', 'Pace', 'FTr', '3PAr', 'TS%', 'off-eFG%', 'off-TOV%',
       'off-ORB%', 'off-FT/FGA', 'dff-eFG%', 'dff-TOV%', 'dff-DRB%',
       'dff-FT/FGA', 'Arena', 'Attend.', 'Attend./G']

# %%
df_misc_stats_15_16['Season'] = '15-16'

# %%
frames = [df_misc_stats_15_16, df_misc_stats_16_17, df_misc_stats_17_18, df_misc_stats_18_19, df_misc_stats_19_20]
df_final_5_yrs = pd.concat(frames)
df_final_5_yrs
# Out:
#     Rk                    Team   Age   W   L  PW  PL    MOV   SOS    SRS  ...  \
# 0    2      San Antonio Spurs*  30.3  67  15  67  15  10.63 -0.36  10.28  ...
# 1    3  Oklahoma City Thunder*  25.8  55  27  59  23   7.28 -0.19   7.09  ...
# 2    4    Cleveland Cavaliers*  28.1  57  25  57  25   6.00 -0.55   5.45  ...
# 3    5   Los Angeles Clippers*  29.7  53  29  53  29   4.28 -0.15   4.13  ...
# 4    6        Toronto Raptors*  26.3  56  26  53  29   4.50 -0.42   4.08  ...
# ..  ..                     ...   ...  ..  ..  ..  ..    ...   ...    ...  ...
# 25  26         New York Knicks  24.5  21  45  20  46  -6.45 -0.26  -6.72  ...
# 26  27       Charlotte Hornets  24.3  23  42  19  46  -6.75 -0.28  -7.03  ...
# 27  28           Atlanta Hawks  24.1  20  47  18  49  -7.97  0.27  -7.71  ...
# 28  29     Cleveland Cavaliers  25.0  19  46  18  47  -7.89  0.12  -7.77  ...
# 29  30   Golden State Warriors  24.4  15  50  16  49  -8.71  0.59  -8.12  ...
#
# ...

# %%
df_final_5_yrs['Team'] = df_final_5_yrs['Team'].str.strip('*')

# %%
plt.subplots(figsize=(20,8))
sns.heatmap(data=df_final_5_yrs.corr(), fmt='.2g', annot=True, cmap='plasma')
plt.tight_layout()

# %%
plt.subplots(figsize=(18,8))

ax = sns.scatterplot(data=df_final_5_yrs, x=df_final_5_yrs['Team'], y=df_final_5_yrs['W'], hue='Season' ,s=80., marker='o')

leg = ax.legend(loc='upper right', bbox_to_anchor=(1.1, 0.7),fontsize=13, shadow=True)

plt.xlabel('Teams')
plt.ylabel('Wins')
plt.title('Last 5 Years\' Winning Numbers - Regular Season')

plt.xticks(rotation=90)
plt.show()
